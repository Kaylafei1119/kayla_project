# %% [markdown]
# #### Import Package Dependencies and Dataset

# %%
import os, sys, re
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import date
import warnings
warnings.filterwarnings('ignore')
# display options
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 100)

# %%
dataset = pd.read_csv('dataset_olist_merged.csv')
dataset.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                 1.0  credit_card
# 1                    2017-10-18                 3.0      voucher
# 2                    2017-10-18                 2.0      voucher
# 3                    2018-08-13                 1.0       boleto
# 4                    2018-09-04                 1.0  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                   1.0          18.12  a54f0611adc9ed256b57ede6b6eb5114
# 1                   1.0           2.00  a54f0611adc9ed256b57ede6b6eb5114
# 2                   1.0          18.59  a54f0611adc9ed256b57ede6b6eb5114
# 3                   1.0         141.46  8d5266042046a06655c8db133d120ba5
# 4                   3.0         179.12  e73b67b67587f7644d5bd1a52deb1b01
#
#    review_score review_comment_title  \
# 0           4.0                  NaN
# 1           4.0                  NaN
# 2           4.0                  NaN
# 3           4.0     Muito boa a loja
# 4           5.0                  NaN
#
#                                                                                 review_comment_message  \
# 0  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 1  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 2  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 3                                                                                 Muito bom o produto.
# 4                                                                                                  NaN
#
#   review_creation_date review_answer_timestamp  \
# 0           2017-10-11     2017-10-12 03:43:48
# 1           2017-10-11     2017-10-12 03:43:48
# 2           2017-10-11     2017-10-12 03:43:48
# 3           2018-08-08     2018-08-08 18:37:50
# 4           2018-08-18     2018-08-22 19:07:58
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 3  af07308b275d755c9edb36a90c618231                     47813     barreiras
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265    vianopolis
#
#   customer_state  order_item_id                        product_id  \
# 0             SP              1  87285b34884572647811a353c7ac498a
# 1             SP              1  87285b34884572647811a353c7ac498a
# 2             SP              1  87285b34884572647811a353c7ac498a
# 3             BA              1  595fac2a385ac33a80bd5114aec74eb8
# 4             GO              1  aa4383b373c6aca5d8797843e5594415
#
#                           seller_id  shipping_limit_date   price  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9  2017-10-06 11:07:15   29.99
# 1  3504c0cb71d7fa48d967e0e4c94d59d9  2017-10-06 11:07:15   29.99
# 2  3504c0cb71d7fa48d967e0e4c94d59d9  2017-10-06 11:07:15   29.99
# 3  289cdb325fb7e7f891c38608bf9e0962  2018-07-30 03:24:27  118.70
# 4  4869f7a5dfa277a7dca6462dcf3b52b2  2018-08-13 08:55:23  159.90
#
#    freight_value  product_category_name  product_name_lenght  \
# 0           8.72  utilidades_domesticas                 40.0
# 1           8.72  utilidades_domesticas                 40.0
# 2           8.72  utilidades_domesticas                 40.0
# 3          22.76             perfumaria                 29.0
# 4          19.22             automotivo                 46.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       268.0                 4.0             500.0
# 2                       268.0                 4.0             500.0
# 3                       178.0                 1.0             400.0
# 4                       232.0                 1.0             420.0
#
#    product_length_cm  product_height_cm  product_width_cm geolocation_state  \
# 0               19.0                8.0              13.0                SP
# 1               19.0                8.0              13.0                SP
# 2               19.0                8.0              13.0                SP
# 3               19.0               13.0              19.0                BA
# 4               24.0               19.0              21.0                GO
#
#   geolocation_city  customer_geolocation_lat  customer_geolocation_lng  \
# 0        sao paulo                -23.576983                -46.587161
# 1        sao paulo                -23.576983                -46.587161
# 2        sao paulo                -23.576983                -46.587161
# 3        barreiras                -12.177924                -44.660711
# 4       vianopolis                -16.745150                -48.514783
#
#    seller_zip_code_prefix     seller_city seller_state  \
# 0                    9350            maua           SP
# 1                    9350            maua           SP
# 2                    9350            maua           SP
# 3                   31570  belo horizonte           SP
# 4                   14840         guariba           SP
#
#    seller_geolocation_lat  seller_geolocation_lng  \
# 0              -23.680729              -46.444238
# 1              -23.680729              -46.444238
# 2              -23.680729              -46.444238
# 3              -19.807681              -43.980427
# 4              -21.363502              -48.229601
#
#   product_category_name_english
# 0                    housewares
# 1                    housewares
# 2                    housewares
# 3                     perfumery
# 4                          auto

# %%
# Euclidean distances between seller and customer
dataset['euclidean_distance'] = (np.sqrt(((dataset['customer_geolocation_lat'] - dataset['seller_geolocation_lat']) ** 2) +
                                          ((dataset['customer_geolocation_lng'] - dataset['seller_geolocation_lng']) ** 2)))

# %% [markdown]
# #### Train-test split

# %%
from sklearn.model_selection import train_test_split

# work with indexes
index_train, index_test = train_test_split(dataset.index, train_size = 0.7, random_state = 42)

# write training and test sets
# copy() does not make a difference here but it's better to be explicit
df_train = dataset.loc[index_train, :].copy()
df_test = dataset.loc[index_test, :].copy()

# %%
print("Variables in the training set:")
print(df_train.columns.to_list())
print("Variables in the test set:")
print(df_test.columns.to_list())
# Out:
# Variables in the training set:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'geolocation_state', 'geolocation_city', 'customer_geolocation_lat', 'customer_geolocation_lng', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'seller_geolocation_lat', 'seller_geolocation_lng', 'product_category_name_english', 'euclidean_distance']
# Variables in the test set:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'geolocation_state', 'geolocation_city', 'customer_geolocation_lat', 'customer_geolocation_lng', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'seller_geolocation_lat', 'seller_geolocation_lng', 'product_category_name_english', 'euclidean_distance']

# %% [markdown]
# #### Define Target Variable (for classification):
#
# * look at the distribution of response variable `y`

# %%
df_train['review_score'] = df_train['review_score'].apply(lambda x: 1 if x > 3 else 0)
df_test['review_score'] = df_test['review_score'].apply(lambda x: 1 if x > 3 else 0)

# %%
df_train['review_score'].value_counts().reset_index()
# Out:
#    review_score  count
# 0             1  64598
# 1             0  21507

# %%
y_train = df_train['review_score'].to_numpy()
y_test = df_test['review_score'].to_numpy()

# %%
print(df_train.shape)
print(df_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (86105, 47)
# (36903, 47)
# (86105,)
# (36903,)

# %% [markdown]
# #### Initial Table Inspection

# %%
df_train.isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                    0
# order_delivered_carrier_date       883
# order_delivered_customer_date     1836
# order_estimated_delivery_date        0
# payment_sequential                   2
# payment_type                         2
# payment_installments                 2
# payment_value                        2
# review_id                          689
# review_score                         0
# review_comment_title             75878
# review_comment_message           49934
# review_creation_date               689
# review_answer_timestamp            689
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name                0
# product_name_lenght                  0
# product_description_lenght           0
# product_photos_qty                   0
# product_weight_g                     0
# product_length_cm                    0
# product_height_cm                    0
# product_width_cm                     0
# geolocation_state                    0
# geolocation_city                     0
# customer_geolocation_lat             0
# customer_geolocation_lng             0
# seller_zip_code_prefix               0
# seller_city                          0
# seller_state                         0
# seller_geolocation_lat               0
# seller_geolocation_lng               0
# product_category_name_english        0
# euclidean_distance                   0
# dtype: int64

# %% [markdown]
# #### Detect Data Types of Variables (Features)

# %%
from dabl import detect_types # useful for data exploration, from tutorial

detected = detect_types(df_train)
detected
# Out:
#                                continuous  dirty_float  low_card_int_ordinal  \
# order_id                            False        False                 False
# customer_id                         False        False                 False
# order_status                        False        False                 False
# order_purchase_timestamp            False        False                 False
# order_approved_at                   False        False                 False
# order_delivered_carrier_date        False        False                 False
# order_delivered_customer_date       False        False                 False
# order_estimated_delivery_date       False        False                 False
# payment_sequential                  False        False                 False
# payment_type                        False        False                 False
# payment_installments                 True        False                 False
# payment_value                        True        False                 False
# review_id                           False        False                 False
# review_score                        False        False                 False
# review_comment_title                False        False                 False
# review_comment_message              False        False                 False
# review_creation_date                False        False                 False
# review_answer_timestamp             False        False                 False
# customer_unique_id                  False        False                 False
# customer_zip_code_prefix             True        False                 False
# customer_city                       False        False                 False
# customer_state                      False        False                 False
# order_item_id                       False        False                 False
# product_id                          False        False                 False
# seller_id                           False        False                 False
# shipping_limit_date                 False        False                 False
# price                                True        False                 False
# freight_value                        True        False                 False
# product_category_name               False        False                 False
# product_name_lenght                 False        False                  True
# product_description_lenght           True        False                 False
# product_photos_qty                  False        False                  True
# product_weight_g                     True        False                 False
# product_length_cm                    True        False                 False
# product_height_cm                    True        False                 False
# product_width_cm                     True        False                 False
# geolocation_state                   False        False                 False
# geolocation_city                    False        False                 False
# customer_geolocation_lat             True        False                 False
# customer_geolocation_lng             True        False                 False
# seller_zip_code_prefix               True        False                 False
# seller_city                         False        False                 False
# seller_state                        False        False                 False
# seller_geolocation_lat               True        False                 False
# seller_geolocation_lng               True        False                 False
# product_category_name_english       False        False                 False
# euclidean_distance                   True        False                 False
#
#                                low_card_int_categorical  categorical   date  \
# order_id                                          False        False  False
# customer_id                                       False        False  False
# order_status                                      False        False  False
# order_purchase_timestamp                          False        False   True
# order_approved_at                                 False        False   True
# order_delivered_carrier_date                      False        False   True
# order_delivered_customer_date                     False        False   True
# order_estimated_delivery_date                     False        False   True
# payment_sequential                                False        False  False
# payment_type                                      False         True  False
# payment_installments                              False        False  False
# payment_value                                     False        False  False
# review_id                                         False        False  False
# review_score                                      False         True  False
# review_comment_title                              False        False  False
# review_comment_message                            False        False  False
# review_creation_date                              False        False  False
# review_answer_timestamp                           False        False   True
# customer_unique_id                                False        False  False
# customer_zip_code_prefix                          False        False  False
# customer_city                                     False        False  False
# customer_state                                    False         True  False
# order_item_id                                      True        False  False
# product_id                                        False        False  False
# seller_id                                         False        False  False
# shipping_limit_date                               False        False   True
# price                                             False        False  False
# freight_value                                     False        False  False
# product_category_name                             False         True  False
# product_name_lenght                               False        False  False
# product_description_lenght                        False        False  False
# product_photos_qty                                False        False  False
# product_weight_g                                  False        False  False
# product_length_cm                                 False        False  False
# product_height_cm                                 False        False  False
# product_width_cm                                  False        False  False
# geolocation_state                                 False         True  False
# geolocation_city                                  False        False  False
# customer_geolocation_lat                          False        False  False
# customer_geolocation_lng                          False        False  False
# seller_zip_code_prefix                            False        False  False
# seller_city                                       False         True  False
# seller_state                                      False         True  False
# seller_geolocation_lat                            False        False  False
# seller_geolocation_lng                            False        False  False
# product_category_name_english                     False         True  False
# euclidean_distance                                False        False  False
#
#                                free_string  useless
# order_id                              True    False
# customer_id                           True    False
# order_status                         False     True
# order_purchase_timestamp             False    False
# order_approved_at                    False    False
# order_delivered_carrier_date         False    False
# order_delivered_customer_date        False    False
# order_estimated_delivery_date        False    False
# payment_sequential                   False     True
# payment_type                         False    False
# payment_installments                 False    False
# payment_value                        False    False
# review_id                             True    False
# review_score                         False    False
# review_comment_title                  True    False
# review_comment_message                True    False
# review_creation_date                  True    False
# review_answer_timestamp              False    False
# customer_unique_id                    True    False
# customer_zip_code_prefix             False    False
# customer_city                         True    False
# customer_state                       False    False
# order_item_id                        False    False
# product_id                            True    False
# seller_id                             True    False
# shipping_limit_date                  False    False
# price                                False    False
# freight_value                        False    False
# product_category_name                False    False
# product_name_lenght                  False    False
# product_description_lenght           False    False
# product_photos_qty                   False    False
# product_weight_g                     False    False
# product_length_cm                    False    False
# product_height_cm                    False    False
# product_width_cm                     False    False
# geolocation_state                    False    False
# geolocation_city                      True    False
# customer_geolocation_lat             False    False
# customer_geolocation_lng             False    False
# seller_zip_code_prefix               False    False
# seller_city                          False    False
# seller_state                         False    False
# seller_geolocation_lat               False    False
# seller_geolocation_lng               False    False
# product_category_name_english        False    False
# euclidean_distance                   False    False

# %%
#### 自行判断是否真的是useless features，并且手动筛选被判断成其他datatype的columns中有哪些是用不上的
useless_features = detected[detected['useless'] == True].index.to_list()
useless_features
# Out:
# ['order_status', 'payment_sequential']

# %%
df_train['order_status'].value_counts().reset_index()

# df = df[df['order_status'] == 'delivered'].copy()
# Out:
#   order_status  count
# 0    delivered  84268
# 1      shipped    896
# 2     canceled    410
# 3   processing    263
# 4     invoiced    261
# 5  unavailable      4
# 6     approved      3

# %%
df_train['payment_sequential'].value_counts().reset_index().head(5)
# Out:
#    payment_sequential  count
# 0                 1.0  82374
# 1                 2.0   2480
# 2                 3.0    478
# 3                 4.0    237
# 4                 5.0    140

# %%
df_train['payment_sequential'].value_counts().reset_index().head(5)
# Out:
#    payment_sequential  count
# 0                 1.0  82374
# 1                 2.0   2480
# 2                 3.0    478
# 3                 4.0    237
# 4                 5.0    140

# %%
detected.columns
# Out:
# Index(['continuous', 'dirty_float', 'low_card_int_ordinal',
#        'low_card_int_categorical', 'categorical', 'date', 'free_string',
#        'useless'],
#       dtype='object')

# %%
### continuous variables
print("Continuous variables:\n", detected[detected['continuous'] == True].index)

### float
print("Float variables: \n", detected[detected['dirty_float'] == True].index)

### low_card_int_ordinal
print("low_card_int_ordinal variables: \n", detected[detected['low_card_int_ordinal'] == True].index)

### categorical
print("Categorical variables: \n", detected[detected['categorical'] == True].index)

### date
print("Datetime variables: \n", detected[detected['date'] == True].index)

### free_string
print("String variables: \n", detected[detected['free_string'] == True].index)
# Out:
# Continuous variables:
#  Index(['payment_installments', 'payment_value', 'customer_zip_code_prefix',
#        'price', 'freight_value', 'product_description_lenght',
#        'product_weight_g', 'product_length_cm', 'product_height_cm',
#        'product_width_cm', 'customer_geolocation_lat',
#        'customer_geolocation_lng', 'seller_zip_code_prefix',
#        'seller_geolocation_lat', 'seller_geolocation_lng',
#        'euclidean_distance'],
#       dtype='object')
# Float variables:
#  Index([], dtype='object')
# low_card_int_ordinal variables:
#  Index(['product_name_lenght', 'product_photos_qty'], dtype='object')
# Categorical variables:
#  Index(['payment_type', 'review_score', 'customer_state',
#        'product_category_name', 'geolocation_state', 'seller_city',
#        'seller_state', 'product_category_name_english'],
#       dtype='object')
# Datetime variables:
#  Index(['order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'review_answer_timestamp',
#        'shipping_limit_date'],
#       dtype='object')
# String variables:
#  Index(['order_id', 'customer_id', 'review_id', 'review_comment_title',
#        'review_comment_message', 'review_creation_date', 'customer_unique_id',
#        'customer_city', 'product_id', 'seller_id', 'geolocation_city'],
#       dtype='object')

# %%
### define new feature based on existing feature
df_train['price_category'] = df_train['price'].apply(
    lambda x: 'expensive' if x >= 139 else ('affordable' if x >= 40 and x < 139 else 'cheap'))
df_test['price_category'] = df_test['price'].apply(
    lambda x: 'expensive' if x >= 139 else ('affordable' if x >= 40 and x < 139 else 'cheap'))

# %% [markdown]
# #### Date Time Variables

# %%
lst_datetime = detected[detected['date'] == True].index.to_list()

for timestamp in lst_datetime:
    df[timestamp] = pd.to_datetime(df[timestamp])

df['approving_time'] = df[['order_purchase_timestamp','order_approved_at']].apply(
    lambda row : str(row['order_approved_at'] - row['order_purchase_timestamp']).split(' ')[0], axis=1
)
df['processing_time'] = df[['order_approved_at','order_delivered_carrier_date']].apply(
    lambda row : str(row['order_delivered_carrier_date'] - row['order_approved_at']).split(' ')[0], axis=1
)
df['delivery_time'] = df[['order_delivered_carrier_date','order_delivered_customer_date']].apply(
    lambda row : str(row['order_delivered_customer_date'] - row['order_delivered_carrier_date']).split(' ')[0], axis=1
)
df['delivered_on_time'] = df[['order_delivered_customer_date','order_estimated_delivery_date']].apply(
    lambda row : 1 if row['order_delivered_customer_date'] <= row['order_estimated_delivery_date'] else 0, axis=1
)

df['delivered_late'] = df[['order_delivered_customer_date','order_estimated_delivery_date']].apply(
    lambda row : 0 if row['order_delivered_customer_date'] <= row['order_estimated_delivery_date'] else 1, axis=1
)

df['seller_on_time'] = df[['order_delivered_carrier_date','shipping_limit_date']].apply(
    lambda row : 1 if row['order_delivered_carrier_date'] <= row['shipping_limit_date'] else 0, axis=1
)

df['order_completion_time'] = df[['order_delivered_customer_date','order_purchase_timestamp']].apply(
    lambda row : str(row['order_delivered_customer_date'] - row['order_purchase_timestamp']).split(' ')[0], axis=1
)


df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                 1.0  credit_card
# 1                    2017-10-18                 3.0      voucher
# 2                    2017-10-18                 2.0      voucher
# 3                    2018-08-13                 1.0       boleto
# 4                    2018-09-04                 1.0  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                   1.0          18.12  a54f0611adc9ed256b57ede6b6eb5114
# 1                   1.0           2.00  a54f0611adc9ed256b57ede6b6eb5114
# 2                   1.0          18.59  a54f0611adc9ed256b57ede6b6eb5114
# 3                   1.0         141.46  8d5266042046a06655c8db133d120ba5
# 4                   3.0         179.12  e73b67b67587f7644d5bd1a52deb1b01
#
#    review_score review_comment_title  \
# 0           4.0                  NaN
# 1           4.0                  NaN
# 2           4.0                  NaN
# 3           4.0     Muito boa a loja
# 4           5.0                  NaN
#
#                                                                                 review_comment_message  \
# 0  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 1  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 2  Não testei o produto ainda, mas ele veio correto e em boas condições. Apenas a caixa que veio be...
# 3                                                                                 Muito bom o produto.
# 4                                                                                                  NaN
#
#   review_creation_date review_answer_timestamp  \
# 0           2017-10-11     2017-10-12 03:43:48
# 1           2017-10-11     2017-10-12 03:43:48
# 2           2017-10-11     2017-10-12 03:43:48
# 3           2018-08-08     2018-08-08 18:37:50
# 4           2018-08-18     2018-08-22 19:07:58
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 3  af07308b275d755c9edb36a90c618231                     47813     barreiras
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265    vianopolis
#
#   customer_state  order_item_id                        product_id  \
# 0             SP              1  87285b34884572647811a353c7ac498a
# 1             SP              1  87285b34884572647811a353c7ac498a
# 2             SP              1  87285b34884572647811a353c7ac498a
# 3             BA              1  595fac2a385ac33a80bd5114aec74eb8
# 4             GO              1  aa4383b373c6aca5d8797843e5594415
#
#                           seller_id shipping_limit_date   price  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9 2017-10-06 11:07:15   29.99
# 1  3504c0cb71d7fa48d967e0e4c94d59d9 2017-10-06 11:07:15   29.99
# 2  3504c0cb71d7fa48d967e0e4c94d59d9 2017-10-06 11:07:15   29.99
# 3  289cdb325fb7e7f891c38608bf9e0962 2018-07-30 03:24:27  118.70
# 4  4869f7a5dfa277a7dca6462dcf3b52b2 2018-08-13 08:55:23  159.90
#
#    freight_value  product_category_name  product_name_lenght  \
# 0           8.72  utilidades_domesticas                 40.0
# 1           8.72  utilidades_domesticas                 40.0
# 2           8.72  utilidades_domesticas                 40.0
# 3          22.76             perfumaria                 29.0
# 4          19.22             automotivo                 46.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       268.0                 4.0             500.0
# 2                       268.0                 4.0             500.0
# 3                       178.0                 1.0             400.0
# 4                       232.0                 1.0             420.0
#
#    product_length_cm  product_height_cm  product_width_cm geolocation_state  \
# 0               19.0                8.0              13.0                SP
# 1               19.0                8.0              13.0                SP
# 2               19.0                8.0              13.0                SP
# 3               19.0               13.0              19.0                BA
# 4               24.0               19.0              21.0                GO
#
#   geolocation_city  customer_geolocation_lat  customer_geolocation_lng  \
# 0        sao paulo                -23.576983                -46.587161
# 1        sao paulo                -23.576983                -46.587161
# 2        sao paulo                -23.576983                -46.587161
# 3        barreiras                -12.177924                -44.660711
# 4       vianopolis                -16.745150                -48.514783
#
#    seller_zip_code_prefix     seller_city seller_state  \
# 0                    9350            maua           SP
# 1                    9350            maua           SP
# 2                    9350            maua           SP
# 3                   31570  belo horizonte           SP
# 4                   14840         guariba           SP
#
#    seller_geolocation_lat  seller_geolocation_lng  \
# 0              -23.680729              -46.444238
# 1              -23.680729              -46.444238
# 2              -23.680729              -46.444238
# 3              -19.807681              -43.980427
# 4              -21.363502              -48.229601
#
#   product_category_name_english approving_time processing_time delivery_time  \
# 0                    housewares              0               2             6
# 1                    housewares              0               2             6
# 2                    housewares              0               2             6
# 3                     perfumery              1               0            12
# 4                          auto              0               0             9
#
#    delivered_on_time  delivered_late  seller_on_time  euclidean_distance  \
# 0                  1               0               1            0.176608
# 1                  1               0               1            0.176608
# 2                  1               0               1            0.176608
# 3                  1               0               1            7.660024
# 4                  1               0               1            4.627149
#
#   order_completion_time
# 0                     8
# 1                     8
# 2                     8
# 3                    13
# 4                     9

# %%
df[df['order_status']=='delivered']['delivered_late'].value_counts().reset_index()
# Out:
#    delivered_late   count
# 0               0  110899
# 1               1    9480

# %%
df[['delivered_on_time','delivered_late']].value_counts().reset_index()
# Out:
#    delivered_on_time  delivered_late   count
# 0                  1               0  110906
# 1                  0               1   12102

# %%
df[df['approving_time'] != 'NaT']
# df = df[df['processing_time'] != 'NaT']
# df = df[df['delivery_time'] != 'NaT']
df['delivered_on_time'].value_counts().reset_index()
# Out:
#    delivered_on_time   count
# 0                  1  110906
# 1                  0   12102

# %%
df['delivered_on_time'].value_counts().reset_index()
# Out:
#    delivered_on_time   count
# 0                  1  110906
# 1                  0   12102

# %%
lst_duration = ['approving_time','processing_time','delivery_time','delivered_on_time','delivered_late','seller_on_time','order_completion_time']

# %%
df[lst_duration].dtypes
# Out:
# approving_time           object
# processing_time          object
# delivery_time            object
# delivered_on_time         int64
# delivered_late            int64
# seller_on_time            int64
# order_completion_time    object
# dtype: object

# %% [markdown]
# #### Continuous Variables

# %%
lst_continuous = detected[detected['continuous'] == True].index.to_list()

df[lst_continuous]
# Out:
#         payment_installments  payment_value  review_score  \
# 0                        1.0          18.12           4.0
# 1                        1.0           2.00           4.0
# 2                        1.0          18.59           4.0
# 3                        1.0         141.46           4.0
# 4                        3.0         179.12           5.0
# ...                      ...            ...           ...
# 123003                   4.0         441.16           2.0
# 123004                   4.0         441.16           2.0
# 123005                   4.0         441.16           2.0
# 123006                   1.0          86.86           5.0
# 123007                   1.0          86.86           5.0
#
#         customer_zip_code_prefix   price  freight_value  \
# 0                           3149   29.99           8.72
# 1                           3149   29.99           8.72
# 2                           3149   29.99           8.72
# 3                          47813  118.70          22.76
# 4                          75265  159.90          19.22
# ...                          ...     ...            ...
# 123003                     28685  179.99          40.59
# 123004                     28685  179.99          40.59
# 123005                     28685  179.99          40.59
# 123006                     83750   68.50          18.36
# 123007                     83750   68.50          18.36
#
#         product_description_lenght  product_weight_g  product_length_cm  \
# 0                            268.0             500.0               19.0
# 1                            268.0             500.0               19.0
# 2                            268.0             500.0               19.0
# 3                            178.0             400.0               19.0
# 4                            232.0             420.0               24.0
# ...                            ...               ...                ...
# 123003                      1893.0            6550.0               20.0
# 123004                      1893.0            6550.0               20.0
# 123005                      1893.0            6550.0               20.0
# 123006                       569.0             150.0               16.0
# 123007                       569.0             150.0               16.0
#
#         product_height_cm  product_width_cm  customer_geolocation_lat  \
# 0                     8.0              13.0                -23.576983
# 1                     8.0              13.0                -23.576983
# 2                     8.0              13.0                -23.576983
# 3                    13.0              19.0                -12.177924
# 4                    19.0              21.0                -16.745150
# ...                   ...               ...                       ...
# 123003               20.0              20.0                -22.562789
# 123004               20.0              20.0                -22.563113
# 123005               20.0              20.0                -22.562789
# 123006                7.0              15.0                -25.764308
# 123007                7.0              15.0                -25.764308
#
#         customer_geolocation_lng  seller_zip_code_prefix  \
# 0                     -46.587161                    9350
# 1                     -46.587161                    9350
# 2                     -46.587161                    9350
# 3                     -44.660711                   31570
# 4                     -48.514783                   14840
# ...                          ...                     ...
# 123003                -42.694844                   37175
# 123004                -42.692414                   37175
# 123005                -42.694844                   37175
# 123006                -49.720376                   14407
# 123007                -49.720376                   14407
#
#         seller_geolocation_lat  seller_geolocation_lng  euclidean_distance
# 0                   -23.680729              -46.444238            0.176608
# 1                   -23.680729              -46.444238            0.176608
# 2                   -23.680729              -46.444238            0.176608
# 3                   -19.807681              -43.980427            7.660024
# 4                   -21.363502              -48.229601            4.627149
# ...                        ...                     ...                 ...
# 123003              -20.940578              -45.827237            3.527529
# 123004              -20.940578              -45.827237            3.529836
# 123005              -20.940578              -45.827237            3.527529
# 123006              -20.496232              -47.418448            5.749043
# 123007              -20.498886              -47.416388            5.747436
#
# [123008 rows x 17 columns]

# %%
df[lst_continuous].dtypes
# Out:
# payment_installments          float64
# payment_value                 float64
# review_score                  float64
# customer_zip_code_prefix        int64
# price                         float64
# freight_value                 float64
# product_description_lenght    float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# customer_geolocation_lat      float64
# customer_geolocation_lng      float64
# seller_zip_code_prefix          int64
# seller_geolocation_lat        float64
# seller_geolocation_lng        float64
# euclidean_distance            float64
# dtype: object

# %%
#### 并不是所有的都是有意义的numerical variables 我们需要通过business判断来看那些是真的numerical 可以用作model prediction的features
lst_numerical = ['payment_value','review_score','price','freight_value','product_weight_g',
                 'product_length_cm','product_height_cm','product_width_cm']

lst_continuous_others = list(set(lst_continuous) - set(lst_numerical))

print(lst_numerical)
print(lst_continuous_others)
# Out:
# ['payment_value', 'review_score', 'price', 'freight_value', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
# ['seller_geolocation_lng', 'seller_zip_code_prefix', 'customer_geolocation_lng', 'payment_installments', 'customer_zip_code_prefix', 'customer_geolocation_lat', 'product_description_lenght', 'seller_geolocation_lat']

# %%
corr = df[lst_continuous].corr()

plt.figure(figsize=(11, 7))  # Width, Height in inches
sns.heatmap(corr, annot=True, fmt='.2g')
plt.show()

# %%
from tutorial4 import distplots, crosstabplots
distplots(df[lst_continuous])
plt.show()

# %%
from tutorial4 import regplots

fig, ax = regplots(df[lst_continuous], df['delivered_late'])
plt.show()

# %% [markdown]
# #### Categorical Variables

# %%
lst_categorical = detected[detected['categorical'] == True].index.to_list()

df[lst_categorical]
# Out:
#        payment_type review_creation_date customer_state  \
# 0       credit_card           2017-10-11             SP
# 1           voucher           2017-10-11             SP
# 2           voucher           2017-10-11             SP
# 3            boleto           2018-08-08             BA
# 4       credit_card           2018-08-18             GO
# ...             ...                  ...            ...
# 123003  credit_card  2018-01-26 00:00:00             RJ
# 123004  credit_card  2018-01-26 00:00:00             RJ
# 123005  credit_card  2018-01-26 00:00:00             RJ
# 123006   debit_card  2018-03-17 00:00:00             PR
# 123007   debit_card  2018-03-17 00:00:00             PR
#
#          product_category_name geolocation_state     seller_city seller_state  \
# 0        utilidades_domesticas                SP            maua           SP
# 1        utilidades_domesticas                SP            maua           SP
# 2        utilidades_domesticas                SP            maua           SP
# 3                   perfumaria                BA  belo horizonte           SP
# 4                   automotivo                GO         guariba           SP
# ...                        ...               ...             ...          ...
# 123003  informatica_acessorios                RJ        ilicinea           MG
# 123004  informatica_acessorios                RJ        ilicinea           MG
# 123005  informatica_acessorios                RJ        ilicinea           MG
# 123006            beleza_saude                PR          franca           SP
# 123007            beleza_saude                PR          franca           SP
#
#        product_category_name_english
# 0                         housewares
# 1                         housewares
# 2                         housewares
# 3                          perfumery
# 4                               auto
# ...                              ...
# 123003         computers_accessories
# 123004         computers_accessories
# 123005         computers_accessories
# 123006                 health_beauty
# 123007                 health_beauty
#
# [123008 rows x 8 columns]
